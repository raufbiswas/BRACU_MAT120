# %% [markdown]
# #Differential Equation(Numerical Method)

# %%
import sympy as sp
from sympy import *
sp.init_printing()
x,y,z = sp.symbols('x y z')

# %%
import scipy
from scipy.integrate import odeint
import numpy as np

# %%
#ordinary differential equation
#odient(function, y0=, t=, tfirst= True)

# %%
dtheta_dt = lambda t,theta: -2.2067e-12*(theta**4-81e0)

# %%
#or
# def dtheta_dt(t,theta):
#     return -2.2067e-12(theta**4-81e0)

# %%
t_val1 = np.linspace(0,100,50)

# %%
solve1 = odeint(dtheta_dt, y0= 1200, t= t_val1, tfirst= True)
solve1
# Out:
# array([[1200.        ],
#        [1190.80437697],
#        [1181.88427813],
#        [1173.22558814],
#        [1164.81518249],
#        [1156.64086704],
#        [1148.69128831],
#        [1140.95584871],
#        [1133.42465202],
#        [1126.08844473],
#        [1118.93857021],
#        [1111.96688847],
#        [1105.165772  ],
#        [1098.52804974],
#        [1092.04697488],
#        [1085.71619033],
#        [1079.52970085],
#        [1073.48184823],
#        [1067.56728529],
#        [1061.78095531],
#        [1056.11806781],
#        [1050.5740867 ],
#        [1045.14471435],
#        [1039.82586577],
#        [1034.61366349],
#        [1029.50442072],
#        [1024.49462984],
#        [1019.580952  ],
#        [1014.7602058 ],
#        [1010.02935871],
#        [1005.38551706],
#        [1000.82591893],
#        [ 996.34792554],
#        [ 991.94901495],
#        [ 987.62677437],
#        [ 983.37889533],
#        [ 979.20316866],
#        [ 975.09747651],
# ...

# %%
# a = np.array([[1,2,3,4],[5,6,7,8]])
# a.shape

# %%
solve1.shape
# Out:
# (50, 1)

# %%
#solve1[row_index,column_index]

# %%
solve1[49,0]
# Out:
# 930.628052759242

# %%
dv_dt = lambda t,v: 10-v**2

# %%
t_val2 = np.linspace(0,100,50)

# %%
solve2 = odeint(dv_dt, y0= 0, t= t_val2, tfirst= True)
solve2
solve2.shape
# Out:
# (50, 1)

# %%
solve2[49,0]
# Out:
# 3.1622776601683795

# %% [markdown]
# OR

# %%
expr = lambda t,v,g,b: g-b*v**2
solve = odeint(expr, y0= 0, t = t_val, args= (10,1), tfirst = True)
solve
solve.shape
# Out:
# (50, 1)

# %%
solve[49,0]
# Out:
# 3.1622776601683795
