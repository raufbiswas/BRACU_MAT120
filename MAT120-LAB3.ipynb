# %%
#numerical integration
#Gauss Quadrature
#Rumberg Method

# %%
import sympy as sp
from sympy import *
sp.init_printing()
x = sp.symbols('x')

# %%
import sympy as sp
from sympy import *
sp.init_printing()
x = sp.symbols('x')
expr = 1/(5+x**2)
expr
val = sp.integrate(expr,x)
val
# Out:
#        ⎛√5⋅x⎞
# √5⋅atan⎜────⎟
#        ⎝ 5  ⎠
# ─────────────
#       5

# %% [markdown]
# #Indefinite

# %%
expr1 = sp.sin(x)
expr1
# Out:
# sin(x)

# %%
val1 = sp.integrate(expr1,x)
val1
# Out:
# -cos(x)

# %%
expr2 = sp.exp(-x)*x**2*sp.cos(x)
expr2
# Out:
#  2  -x
# x ⋅ℯ  ⋅cos(x)

# %%
expr2 = sp.exp(-x)*x**2*sp.cos(x)
val2= sp.integrate(expr2,x)
val2
# Out:
#  2  -x           2  -x                          -x           -x
# x ⋅ℯ  ⋅sin(x)   x ⋅ℯ  ⋅cos(x)      -x          ℯ  ⋅sin(x)   ℯ  ⋅cos(x)
# ───────────── - ───────────── + x⋅ℯ  ⋅sin(x) + ────────── + ──────────
#       2               2                            2            2

# %%
simplify(val2)
# Out:
#    ⎛   2    ⎛    π⎞        ⎛    π⎞        ⎛    π⎞      ⎛    π⎞⎞  -x
# √2⋅⎜- x ⋅cos⎜x + ─⎟ + x⋅sin⎜x + ─⎟ - x⋅cos⎜x + ─⎟ + sin⎜x + ─⎟⎟⋅ℯ
#    ⎝        ⎝    4⎠        ⎝    4⎠        ⎝    4⎠      ⎝    4⎠⎠
# ───────────────────────────────────────────────────────────────────
#                                  2

# %%
val2.simplify()
# Out:
#    ⎛   2    ⎛    π⎞        ⎛    π⎞        ⎛    π⎞      ⎛    π⎞⎞  -x
# √2⋅⎜- x ⋅cos⎜x + ─⎟ + x⋅sin⎜x + ─⎟ - x⋅cos⎜x + ─⎟ + sin⎜x + ─⎟⎟⋅ℯ
#    ⎝        ⎝    4⎠        ⎝    4⎠        ⎝    4⎠      ⎝    4⎠⎠
# ───────────────────────────────────────────────────────────────────
#                                  2

# %%
expr3 = sp.exp(-5*x)*sp.sin(x)**3
expr3
# Out:
#  -5⋅x    3
# ℯ    ⋅sin (x)

# %%
val3= sp.integrate(expr3,x)
val3.simplify()
# Out:
#                                                        -5⋅x
# (-255⋅sin(x) + 65⋅sin(3⋅x) - 51⋅cos(x) + 39⋅cos(3⋅x))⋅ℯ
# ───────────────────────────────────────────────────────────
#                             1768

# %%
expr4 = (((1+sqrt(x))**(sp.Rational(1,3)))/sqrt(x))
expr4
# Out:
# 3 ________
# ╲╱ √x + 1
# ──────────
#     √x

# %%
val4 = sp.integrate(expr4, x)
val4.simplify()
# Out:
#           4/3
# 3⋅(√x + 1)
# ─────────────
#       2

# %% [markdown]
# #definite

# %%
expr5 = sp.exp(x)/sqrt(sp.exp(x)+9)
expr5
# Out:
#       x
#      ℯ
# ───────────
#    ________
#   ╱  x
# ╲╱  ℯ  + 9

# %%
val5 = sp.integrate(expr5, (x,0,sp.log(4)))
val5.simplify()
# Out:
# -2⋅√10 + 2⋅√13

# %%
val5.evalf()
# Out:
# 0.886547230591220
